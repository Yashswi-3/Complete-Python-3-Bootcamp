# %%
name = "Yashswi"

# %%
print(name)
# Out:
# Yashswi

# %%
name[0],name[1],name[2],name[3],name[4],name[5],name[6]
# Out:
# ('Y', 'a', 's', 'h', 's', 'w', 'i')

# %%
name[:-1]
# Out:
# 'Yashsw'

# %%
name[::-1]
# Out:
# 'iwshsaY'

# %%
name[1:6]
# Out:
# 'ashsw'

# %%
name[0:5]
# Out:
# 'Yashs'

# %%
test = "Hello World"

# %%
test[:5]
# Out:
# 'Hello'

# %%
test[5]
# Out:
# ' '

# %%
name[::2]
# Out:
# 'Yssi'

# %%
print("Hello i am %s" %'yashswi')
# Out:
# Hello i am yashswi

# %%
print('i am going to be %r' %'Greate Programmer' )
# Out:
# i am going to be 'Greate Programmer'

# %%
print("How are you going to vote, %s" %"BJP ?")
# Out:
# How are you goint to vote, BJP ?

# %%
print("I am using moudlo d operator that rounds off 3.75 to %d" %3.75)
# Out:
# I am using moudlo d operator that rounds off 3.75 to 3

# %%
print("Now i will be using moudle 6 . 2 f which will give me %6.2f" %(123.456))
# Out:
# Now i will be using moudle 6 . 2 f which will give me 123.46

# %%
print("is point counted ? %1.2f" %123.456789)
# Out:
# is point counted ? 123.46

# %%
print("{} is this".format('yash'))
# Out:
# yash is this

# %%
print("{} is this, what will {}".format('what',"happen"))
# Out:
# what is this, what will happen

# %%
print("{a} is this, what will {b}".format(a='what', b="happen"))
# Out:
# what is this, what will happen
